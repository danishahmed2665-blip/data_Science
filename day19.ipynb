# %%
# Subplots in 1D


import matplotlib.pyplot as plt
#graph one data
year = [2010,2015,2020,2025]
dairy = [100,520,630,400]

#graph two data
year = [1990,2000,2005,2010]
farming =[300,200,250,100]

fig , aux =plt.subplots(1,2)

#this is first graph
aux[0].plot(year,dairy)
aux[0].set_xlabel("year")
aux[0].set_ylabel("dairy")
aux[0].set_title("dairy production")




#this is second graph
aux[1].plot(year,farming)
aux[1].set_xlabel("year")
aux[1].set_ylabel("farming")
aux[1].set_title("farming production")

plt.show()

# %%
# Subplots in 2D



import matplotlib.pyplot as plt
#graph one data
year = [2010,2015,2020,2025]
dairy = [100,520,630,400]

#graph two data
year = [1990,2000,2005,2010]
farming =[300,200,250,100]

#graph three data
college =[10,20,25,30]

#graph four data
transport = [50,75,100,150]

fig , aux =plt.subplots(2,2) #4 cols
#first row and first column
aux[0][0].plot(year,dairy)
aux[0][0].set_xlabel("year")
aux[0][0].set_ylabel("dairy")
aux[0][0].set_title("dairy production")

#first row and second column
aux[0][1].bar(year,farming)
aux[0][1].set_xlabel("year")
aux[0][1].set_ylabel("farming")
aux[0][1].set_title("farming production")

#second row and first column
aux[1][0].pie(year,labels=college)
aux[1][0].set_xlabel("year")
aux[1][0].set_ylabel("college")
aux[1][0].set_title("college production")


#second row and second column
aux[1][1].scatter(year,transport)
aux[1][1].set_xlabel("year")
aux[1][1].set_ylabel("transport")
aux[1][1].set_title("transport production")

plt.tight_layout()



#plt.gcf().canvas.get_supported_filetypes()
plt.savefig("subplot.jpg")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-arya/main/temperature_data.json"
df =pd.read_json(url)


#drop row 3 -> day = wednesday
df.drop(3,inplace=True)


#fill average value -> humidity -> Nan
df["humidity_pct"] = df["humidity_pct"].fillna(df["humidity_pct"].mean())
df

#new cols -> farenhit   |  cell*1.8 -> +32
df["temperature_f"] = df["temperature_c"] * 1.8 + 32

#subplots -> pie
fig,aux = plt.subplots(1,2)
aux[0].plot(df["humidity_pct"], df["temperature_c"])
aux[0].set_xlabel("humidity")
aux[0].set_ylabel("temperature in Celsius")
aux[0].set_title("humidity with Celcius")

aux[1].pie(df["temperature_f"], labels=df["day"])
aux[1].set_title("Temperature in Fahrenheit (Bar chart)")
aux.set_title("humidity with farenhite")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2375/3287184445.py in <cell line: 0>()
#      23 aux[0].set_title("humidity with Celcius")
#      24
# ---> 25 aux[1].pie(df["temperature_f"], labels=df["day"])
#      26 aux[1].set_title("Temperature in Fahrenheit (Bar chart)")
#      27 aux.set_title("humidity with farenhite")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3385             y += expl * math.sin(thetam)
#    3386
# -> 3387             w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3388                                360. * max(theta1, theta2),
#    3389                                facecolor=get_next_color(),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/patches.py in __init__(self, center, r, theta1, theta2, width, **kwargs)
#    1250         self.theta1, self.theta2 = theta1, theta2
#    1251         self._patch_transform = transforms.IdentityTransform()
# -> 1252         self._recompute_path()
#    1253
#    1254     def _recompute_path(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/patches.py in _recompute_path(self)
#    1262
#    1263         # Form the outer ring
# -> 1264         arc = Path.arc(theta1, theta2)
#    1265
#    1266         if self.width is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     959         # number of curve segments to make
#     960         if n is None:
# --> 961             n = int(2 ** np.ceil((eta2 - eta1) / halfpi))
#     962         if n < 1:
#     963             raise ValueError("n must be >= 1 or None")
#
# ValueError: cannot convert float NaN to integer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
# -> 2158                     bbox_inches = self.figure.get_tightbbox(
#    2159                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2160                     if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1846                 # need this conditional....
#    1847                 try:
# -> 1848                     bbox = ax.get_tightbbox(
#    1849                         renderer, bbox_extra_artists=bbox_extra_artists)
#    1850                 except TypeError:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4540
#    4541         for a in bbox_artists:
# -> 4542             bbox = a.get_tightbbox(renderer)
#    4543             if (bbox is not None
#    4544                     and 0 < bbox.width < np.inf
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     362             Returns None if clipping results in no intersection.
#     363         """
# --> 364         bbox = self.get_window_extent(renderer)
#     365         if self.get_clip_on():
#     366             clip_box = self.get_clip_box()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     653
#     654     def get_window_extent(self, renderer=None):
# --> 655         return self.get_path().get_extents(self.get_transform())
#     656
#     657     def _convert_xy_units(self, xy):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     640                 # as can the ends of the curve
#     641                 xys.append(curve([0, *dzeros, 1]))
# --> 642             xys = np.concatenate(xys)
#     643         if len(xys):
#     644             return Bbox([xys.min(axis=0), xys.max(axis=0)])
#
# ValueError: need at least one array to concatenate
